# %%
import pandas as pd
import mysql.connector

# %%
# !pip install mysql-connector-python
# Out:
# Collecting mysql-connector-python
#   Downloading mysql_connector_python-9.0.0-cp38-cp38-macosx_13_0_x86_64.whl.metadata (2.0 kB)
# Downloading mysql_connector_python-9.0.0-cp38-cp38-macosx_13_0_x86_64.whl (14.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.2/14.2 MB 9.6 MB/s eta 0:00:0000:0100:01
# Installing collected packages: mysql-connector-python
# Successfully installed mysql-connector-python-9.0.0

# %%
conn = mysql.connector.connect(
    host="localhost",
    user="root",
    password='',
    port=3306  # Change if necessary
)
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# File /opt/anaconda3/envs/ml-env/lib/python3.8/site-packages/mysql/connector/connection_cext.py:334, in CMySQLConnection._open_connection(self)
#     333 try:
# --> 334     self._cmysql.connect(**cnx_kwargs)
#     335     self._cmysql.converter_str_fallback = self._converter_str_fallback
#
# MySQLInterfaceError: Access denied for user 'root'@'localhost' (using password: NO)
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 conn = mysql.connector.connect(
#       2     host="localhost",
#       3     user="root",
#       4     password='',
#       5     port=3306  # Change if necessary
#       6 )
#
# File /opt/anaconda3/envs/ml-env/lib/python3.8/site-packages/mysql/connector/pooling.py:322, in connect(*args, **kwargs)
#     319         raise ImportError(ERROR_NO_CEXT)
#     321 if CMySQLConnection and not use_pure:
# --> 322     return CMySQLConnection(*args, **kwargs)
#     323 return MySQLConnection(*args, **kwargs)
#
# File /opt/anaconda3/envs/ml-env/lib/python3.8/site-packages/mysql/connector/connection_cext.py:151, in CMySQLConnection.__init__(self, **kwargs)
#     149 if kwargs:
#     150     try:
# --> 151         self.connect(**kwargs)
#     152     except Exception:
#     153         self.close()
#
# File /opt/anaconda3/envs/ml-env/lib/python3.8/site-packages/mysql/connector/abstracts.py:1399, in MySQLConnectionAbstract.connect(self, **kwargs)
#    1396     self.config(**kwargs)
#    1398 self.disconnect()
# -> 1399 self._open_connection()
#    1401 charset, collation = (
#    1402     kwargs.pop("charset", None),
#    1403     kwargs.pop("collation", None),
#    1404 )
#    1405 if charset or collation:
#
# File /opt/anaconda3/envs/ml-env/lib/python3.8/site-packages/mysql/connector/connection_cext.py:339, in CMySQLConnection._open_connection(self)
#     337         self.converter.str_fallback = self._converter_str_fallback
#     338 except MySQLInterfaceError as err:
# --> 339     raise get_mysql_exception(
#     340         msg=err.msg, errno=err.errno, sqlstate=err.sqlstate
#     341     ) from err
#     343 self._do_handshake()
#     345 if (
#     346     not self._ssl_disabled
#     347     and hasattr(self._cmysql, "get_ssl_cipher")
#    (...)
#     352
#     353     # `get_ssl_cipher()` returns the name of the cipher being used.
#
# ProgrammingError: 1045 (28000): Access denied for user 'root'@'localhost' (using password: NO)

# %%
df = pd.read_sql_query('''
		SELECT * FROM (
			SELECT
			CONCAT("Match- ", CAST(ROW_NUMBER() OVER(ORDER BY ID) AS CHAR)) AS 'match_no',
			SUM(batsman_run) AS 'runs_scored',
			SUM(SUM(batsman_run)) OVER w AS 'career_runs',
			AVG(SUM(batsman_run)) OVER w
			FROM ipl_data
			WHERE batter = 'V Kohli'
			GROUP BY ID
			WINDOW w AS (
					ROWS BETWEEN UNBOUNDED PRECEDING AND CURRENT ROW
			)
		) t;
''', conn)

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(df['match_no'], df['career_avg'])
plt.plot(df['match_no'], df['rolling_avg'])
